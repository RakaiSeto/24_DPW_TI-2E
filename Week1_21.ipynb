# %% [markdown]
# <a href="https://colab.research.google.com/github/RakaiSeto/24_DPW_TI-2E/blob/master/Week1_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://instagram.fcgk4-2.fna.fbcdn.net/v/t51.2885-19/493994021_18385041163189576_3088695320510547046_n.jpg?efg=eyJ2ZW5jb2RlX3RhZyI6InByb2ZpbGVfcGljLmRqYW5nby4xMDgwLmMyIn0&_nc_ht=instagram.fcgk4-2.fna.fbcdn.net&_nc_cat=104&_nc_oc=Q6cZ2QGqYV7I_BIx1GFIQOZ1c34L0Borrikw4xcHHDbSocyvSnT_tn7Yhcj_fUKLboKnDao&_nc_ohc=cch0tH9nilEQ7kNvwFzDHll&_nc_gid=sBLFc0gZ7Qhv_c0e6cbShg&edm=AP4sbd4BAAAA&ccb=7-5&oh=00_AfWq18o2gZfqiEe-friMNgQfJOARQjtf9E3EanfLhZiHpQ&oe=68B70531&_nc_sid=7a9f4b"
]

# testing commit

for url in urls:
    image = io.imread(url)
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
    image2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    garis_horizontal = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    garis_vertikal = cv.cvtColor(image, cv.COLOR_BGR2RGB)

    tinggi = image.shape[0]
    lebar = image.shape[1]

    for y in range (lebar):
      garis_horizontal[int((tinggi)/2), y] = [255, 255, 255]

    for x in range (tinggi):
      garis_vertikal[x, int((lebar)/2)] = [255, 255, 255]

    print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
    final_frame = cv.hconcat((image, image2, garis_horizontal, garis_vertikal))
    cv2_imshow(final_frame)
    print('\n')
# Out:
# resolusi image: tinggi x lebar =  276  x  400
# <PIL.Image.Image image mode=RGB size=1600x276>
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=1600x286>
# resolusi image: tinggi x lebar =  540  x  540
# <PIL.Image.Image image mode=RGB size=2160x540>
